# %% [markdown]
# # Estatística descritiva - Avaliação Completa
#
# Neste notebook, iremos carregar os dados, realizar análise estatística e geração dos principais gráficos de avaliação.

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# 📁 Caminho do shapefile local
caminho_geo = r'C:\Users\john-\OneDrive - Universidade Federal da Paraíba\Área de Trabalho\Artigo - Estatística\projeto-evasao\data\processed\brazil_states.geojson'
gdf_brasil = gpd.read_file(caminho_geo)

# 📍 Mapeia nomes dos estados para siglas (UF)
siglas_estados = {
    'Acre': 'AC', 'Alagoas': 'AL', 'Amapá': 'AP', 'Amazonas': 'AM', 'Bahia': 'BA',
    'Ceará': 'CE', 'Distrito Federal': 'DF', 'Espírito Santo': 'ES', 'Goiás': 'GO',
    'Maranhão': 'MA', 'Mato Grosso': 'MT', 'Mato Grosso do Sul': 'MS', 'Minas Gerais': 'MG',
    'Pará': 'PA', 'Paraíba': 'PB', 'Paraná': 'PR', 'Pernambuco': 'PE', 'Piauí': 'PI',
    'Rio de Janeiro': 'RJ', 'Rio Grande do Norte': 'RN', 'Rio Grande do Sul': 'RS',
    'Rondônia': 'RO', 'Roraima': 'RR', 'Santa Catarina': 'SC', 'São Paulo': 'SP',
    'Sergipe': 'SE', 'Tocantins': 'TO'
}
gdf_brasil['UF'] = gdf_brasil['name'].map(siglas_estados)

# 🎯 Lista de variáveis a serem mapeadas
variaveis = [
    'NOTA_PADRONIZADA_-_IDD',
    'NOTA_PADRONIZADA_-_ORGANIZAÇÃO_DIDÁTICO-PEDAGÓGICA',
    'NOTA_PADRONIZADA_-_INFRAESTRUTURA_E_INSTALAÇÕES_FÍSICAS',
    'NOTA_PADRONIZADA_-_OPORTUNIDADE_DE_AMPLIAÇÃO_DA_FORMAÇÃO',
    'NOTA_PADRONIZADA_-_MESTRES',
    'NOTA_PADRONIZADA_-_DOUTORES',
    'MEDIA_CONCEITO_ENADE_(CONTÍNUO)',
    'IDD_(CONTÍNUO)',
    'CONCEITO_MÉDIO_DE_GRADUAÇÃO',
    'IGC_(CONTÍNUO)',
    'TDA',
    'SALARIO',
    'QT_VG_TOTAL_MEDIA'
]

# 🏷️ Nomes curtos para o título dos gráficos
nomes_curto = {
    'NOTA_PADRONIZADA_-_IDD': 'IDD',
    'NOTA_PADRONIZADA_-_ORGANIZAÇÃO_DIDÁTICO-PEDAGÓGICA': 'Org. Didático',
    'NOTA_PADRONIZADA_-_INFRAESTRUTURA_E_INSTALAÇÕES_FÍSICAS': 'Infraestrutura',
    'NOTA_PADRONIZADA_-_OPORTUNIDADE_DE_AMPLIAÇÃO_DA_FORMAÇÃO': 'Oportunidade',
    'NOTA_PADRONIZADA_-_MESTRES': 'Mestres',
    'NOTA_PADRONIZADA_-_DOUTORES': 'Doutores',
    'MEDIA_CONCEITO_ENADE_(CONTÍNUO)': 'Média ENADE',
    'IDD_(CONTÍNUO)': 'IDD Contínuo',
    'CONCEITO_MÉDIO_DE_GRADUAÇÃO': 'Conceito Graduação',
    'IGC_(CONTÍNUO)': 'IGC',
    'TDA': 'TDA',
    'SALARIO': 'Salário',
    'QT_VG_TOTAL_MEDIA': 'Vagas Média'
}

# 📊 Média das variáveis por estado
df['SIGLA_DA_UF'] = df['SIGLA_DA_UF'].str.upper()
media_por_estado = df.groupby('SIGLA_DA_UF')[variaveis].mean().reset_index()

# 🔗 Juntar com o mapa
gdf_merged = gdf_brasil.merge(media_por_estado, left_on='UF', right_on='SIGLA_DA_UF', how='left')

# 🔢 Definir número de linhas e colunas do grid de mapas
import math
n = len(variaveis)
ncols = 4
nrows = math.ceil(n / ncols)

# 🖼️ Criar grid de subplots
fig, axs = plt.subplots(nrows=nrows, ncols=ncols, figsize=(5 * ncols, 4 * nrows))
axs = axs.flatten()

for i, var in enumerate(variaveis):
    gdf_merged.plot(
        column=var,
        cmap='OrRd',
        linewidth=0.5,
        ax=axs[i],
        edgecolor='0.8',
        legend=True
    )
    axs[i].set_title(f'{nomes_curto.get(var, var)}', fontsize=11)
    axs[i].axis('off')

# Remover eixos extras se sobrarem
for j in range(i + 1, len(axs)):
    fig.delaxes(axs[j])

plt.suptitle('Mapas de Calor por Estado – Variáveis Educacionais', fontsize=16)
plt.tight_layout()
plt.show()

# %%
# 📦 Importação de bibliotecas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')
sns.set(style="whitegrid")

# 📁 Leitura dos dados
caminho = r'C:/Users/john-/OneDrive - Universidade Federal da Paraíba/Área de Trabalho/Artigo - Estatística/projeto-evasao/data/processed/ml_iq_2018_2023.csv'
df = pd.read_csv(caminho)

# 🎯 Colunas quantitativas (excluindo SALARIO e QT_VG_TOTAL_MEDIA para boxplot)
colunas_quant_boxplot = [
    'NOTA_PADRONIZADA_-_IDD',
    'NOTA_PADRONIZADA_-_ORGANIZAÇÃO_DIDÁTICO-PEDAGÓGICA',
    'NOTA_PADRONIZADA_-_INFRAESTRUTURA_E_INSTALAÇÕES_FÍSICAS',
    'NOTA_PADRONIZADA_-_OPORTUNIDADE_DE_AMPLIAÇÃO_DA_FORMAÇÃO',
    'NOTA_PADRONIZADA_-_MESTRES',
    'NOTA_PADRONIZADA_-_DOUTORES',
    'MEDIA_CONCEITO_ENADE_(CONTÍNUO)',
    'IDD_(CONTÍNUO)',
    'CONCEITO_MÉDIO_DE_GRADUAÇÃO',
    'IGC_(CONTÍNUO)',
    'TDA'
]

# Para os demais gráficos, incluindo SALARIO e QT_VG_TOTAL_MEDIA
colunas_quant_todas = colunas_quant_boxplot + ['SALARIO', 'QT_VG_TOTAL_MEDIA']

# Dicionário nomes curtos para as variáveis
nomes_curto = {
    'NOTA_PADRONIZADA_-_IDD': 'IDD',
    'NOTA_PADRONIZADA_-_ORGANIZAÇÃO_DIDÁTICO-PEDAGÓGICA': 'Org. Didático',
    'NOTA_PADRONIZADA_-_INFRAESTRUTURA_E_INSTALAÇÕES_FÍSICAS': 'Infraestrutura',
    'NOTA_PADRONIZADA_-_OPORTUNIDADE_DE_AMPLIAÇÃO_DA_FORMAÇÃO': 'Oportunidade',
    'NOTA_PADRONIZADA_-_MESTRES': 'Mestres',
    'NOTA_PADRONIZADA_-_DOUTORES': 'Doutores',
    'MEDIA_CONCEITO_ENADE_(CONTÍNUO)': 'Média ENADE',
    'IDD_(CONTÍNUO)': 'IDD Contínuo',
    'CONCEITO_MÉDIO_DE_GRADUAÇÃO': 'Conceito Graduação',
    'IGC_(CONTÍNUO)': 'IGC',
    'TDA': 'TDA',
    'SALARIO': 'Salário',
    'QT_VG_TOTAL_MEDIA': 'Vagas Média'
}

# ----------------------------------
# 1. Estatísticas Descritivas (com TDA) - substituindo quantis por mediana
# ----------------------------------

desc_stats = df[colunas_quant_todas].agg(['mean', 'median', 'std', 'min', 'max']).T
desc_stats = desc_stats.rename(columns={
    'mean': 'Média',
    'median': 'Mediana',
    'std': 'Desvio Padrão',
    'min': 'Mínimo',
    'max': 'Máximo'
})
desc_stats['Coeficiente de Variação'] = desc_stats['Desvio Padrão'] / desc_stats['Média']

print("### Estatísticas Descritivas Atualizada ###")
display(desc_stats)

# ----------------------------------
# 2. Correlação (Pearson) (com TDA)
# ----------------------------------
correlation_matrix = df[colunas_quant_todas].corr(method='pearson')
print("### Matriz de Correlação (Pearson) ###")
display(correlation_matrix)

# ----------------------------------
# 3. Ranking por variável TDA
# ----------------------------------
ranking_tda = df[['NOME_DA_IES', 'TDA']].groupby('NOME_DA_IES').mean().sort_values(by='TDA', ascending=False)
print("### Ranking TDA por IES ###")
display(ranking_tda)

# ----------------------------------
# 4. Boxplot Geral Agrupado (SEM SALARIO e QT_VG_TOTAL_MEDIA)
# ----------------------------------
fig, axs = plt.subplots(nrows=3, ncols=4, figsize=(18, 10))
axs = axs.flatten()
for i, col in enumerate(colunas_quant_boxplot):
    sns.boxplot(data=df, y=col, ax=axs[i], color='skyblue')
    axs[i].set_title(nomes_curto[col], fontsize=9)
    axs[i].set_ylabel(nomes_curto[col])
    axs[i].set_xlabel('')
for j in range(i + 1, len(axs)):
    fig.delaxes(axs[j])
plt.suptitle("Boxplots das Variáveis (exceto Salário e Vagas)", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# ----------------------------------
# 5. Histogramas Agrupados (incluindo todas as variáveis)
# ----------------------------------
fig, axs = plt.subplots(nrows=4, ncols=4, figsize=(20, 14))
axs = axs.flatten()
for i, col in enumerate(colunas_quant_todas):
    sns.histplot(df[col], kde=True, bins=30, ax=axs[i], color='salmon')
    axs[i].set_title(nomes_curto[col], fontsize=9)
    axs[i].set_xlabel(nomes_curto[col])
    axs[i].set_ylabel('Frequência')
for j in range(i + 1, len(axs)):
    fig.delaxes(axs[j])
plt.suptitle("Histogramas das Variáveis", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# ----------------------------------
# 6. Heatmap de Correlação com nomes curtos nos eixos
# ----------------------------------
labels_curto = [nomes_curto[col] for col in correlation_matrix.columns]

plt.figure(figsize=(14, 12))
sns.heatmap(correlation_matrix,
            annot=True,
            fmt=".2f",
            cmap='coolwarm',
            xticklabels=labels_curto,
            yticklabels=labels_curto)
plt.title("Mapa de Correlação (Pearson)")
plt.tight_layout()
plt.show()

# ----------------------------------
# 7. Dispersão vs IGC (excluindo IGC)
# ----------------------------------
vars_disp = [col for col in colunas_quant_todas if col != 'IGC_(CONTÍNUO)']

n = len(vars_disp)
ncols = 4
nrows = int(np.ceil(n / ncols))

fig, axs = plt.subplots(nrows=nrows, ncols=ncols, figsize=(20, nrows * 4))
axs = axs.flatten()

for i, col in enumerate(vars_disp):
    sns.scatterplot(data=df, x=col, y='IGC_(CONTÍNUO)', ax=axs[i])
    axs[i].set_title(f'Dispersão: {nomes_curto[col]} vs IGC')
    axs[i].set_xlabel(nomes_curto[col])
    axs[i].set_ylabel('IGC')

for j in range(i + 1, len(axs)):
    fig.delaxes(axs[j])

plt.suptitle("Gráficos de Dispersão vs IGC", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# ----------------------------------
# 8. Gráfico de Linhas Horizontal: variáveis no eixo Y, médias no eixo X
# ----------------------------------
media_vars = df[colunas_quant_boxplot].mean()

plt.figure(figsize=(10, 6))
plt.hlines(y=media_vars.index, xmin=0, xmax=media_vars.values, color='skyblue')
plt.plot(media_vars.values, media_vars.index, "o", color='blue')
plt.xlabel('Média')
plt.ylabel('Variáveis')
plt.title('Média das Variáveis (sem Salário e Vagas)')
plt.grid(axis='x')
plt.tight_layout()
plt.show()

# ----------------------------------
# 9. Dispersão de variáveis explicativas vs TDA
# ----------------------------------
vars_exp = [col for col in colunas_quant_boxplot if col != 'TDA']

fig, axs = plt.subplots(nrows=3, ncols=4, figsize=(18, 12))
axs = axs.flatten()

for i, col in enumerate(vars_exp):
    sns.scatterplot(data=df, x=col, y='TDA', ax=axs[i])
    axs[i].set_title(f'{nomes_curto.get(col, col)} vs TDA')
    axs[i].set_xlabel(nomes_curto.get(col, col))
    axs[i].set_ylabel('TDA')

for j in range(i + 1, len(axs)):
    fig.delaxes(axs[j])

plt.suptitle("Dispersão das Variáveis Explicativas vs TDA", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
# Out:
# ### Estatísticas Descritivas Atualizada ###
#                                                           Média      Mediana  \
# NOTA_PADRONIZADA_-_IDD                                 2.686974     2.665456
# NOTA_PADRONIZADA_-_ORGANIZAÇÃO_DIDÁTICO-PEDAGÓGICA     2.513250     2.518189
# NOTA_PADRONIZADA_-_INFRAESTRUTURA_E_INSTALAÇÕES...     2.577177     2.640500
# NOTA_PADRONIZADA_-_OPORTUNIDADE_DE_AMPLIAÇÃO_DA...     2.900473     2.934000
# NOTA_PADRONIZADA_-_MESTRES                             4.353912     4.637750
# NOTA_PADRONIZADA_-_DOUTORES                            3.509263     3.819500
# MEDIA_CONCEITO_ENADE_(CONTÍNUO)                        3.288015     3.348824
# IDD_(CONTÍNUO)                                         2.691831     2.670351
# CONCEITO_MÉDIO_DE_GRADUAÇÃO                            3.132286     3.175627
# IGC_(CONTÍNUO)                                         3.512894     3.529067
# TDA                                                    8.126438     6.000000
# SALARIO                                             3913.294831  3295.802768
# QT_VG_TOTAL_MEDIA                                     84.883394    72.000000
#
#                                                     Desvio Padrão      Mínimo  \
# NOTA_PADRONIZADA_-_IDD                                   0.708318    0.020000
# NOTA_PADRONIZADA_-_ORGANIZAÇÃO_DIDÁTICO-PEDAGÓGICA       0.769656    0.000000
# NOTA_PADRONIZADA_-_INFRAESTRUTURA_E_INSTALAÇÕES...       0.826416    0.000000
# NOTA_PADRONIZADA_-_OPORTUNIDADE_DE_AMPLIAÇÃO_DA...       0.657698    0.000000
# NOTA_PADRONIZADA_-_MESTRES                               0.812271    0.000000
# NOTA_PADRONIZADA_-_DOUTORES                              1.105402    0.000000
# MEDIA_CONCEITO_ENADE_(CONTÍNUO)                          0.832425    0.187888
# IDD_(CONTÍNUO)                                           0.702290    0.021000
# CONCEITO_MÉDIO_DE_GRADUAÇÃO                              0.277828    2.242833
# IGC_(CONTÍNUO)                                           0.458907    2.284978
# TDA                                                      8.079376    0.000000
# SALARIO                                               2235.943095  490.860000
# QT_VG_TOTAL_MEDIA                                       50.267027    0.000000
#
#                                                           Máximo  \
# NOTA_PADRONIZADA_-_IDD                                  5.000000
# NOTA_PADRONIZADA_-_ORGANIZAÇÃO_DIDÁTICO-PEDAGÓGICA      4.764000
# NOTA_PADRONIZADA_-_INFRAESTRUTURA_E_INSTALAÇÕES...      4.806500
# NOTA_PADRONIZADA_-_OPORTUNIDADE_DE_AMPLIAÇÃO_DA...      4.801000
# NOTA_PADRONIZADA_-_MESTRES                              5.000000
# NOTA_PADRONIZADA_-_DOUTORES                             5.000000
# MEDIA_CONCEITO_ENADE_(CONTÍNUO)                         5.000000
# IDD_(CONTÍNUO)                                          5.000000
# CONCEITO_MÉDIO_DE_GRADUAÇÃO                             4.181189
# IGC_(CONTÍNUO)                                          4.471158
# TDA                                                    61.029412
# SALARIO                                             31666.670000
# QT_VG_TOTAL_MEDIA                                     535.000000
#
#                                                     Coeficiente de Variação
# NOTA_PADRONIZADA_-_IDD                                             0.263612
# NOTA_PADRONIZADA_-_ORGANIZAÇÃO_DIDÁTICO-PEDAGÓGICA                 0.306239
# NOTA_PADRONIZADA_-_INFRAESTRUTURA_E_INSTALAÇÕES...                 0.320667
# NOTA_PADRONIZADA_-_OPORTUNIDADE_DE_AMPLIAÇÃO_DA...                 0.226756
# NOTA_PADRONIZADA_-_MESTRES                                         0.186561
# NOTA_PADRONIZADA_-_DOUTORES                                        0.314995
# MEDIA_CONCEITO_ENADE_(CONTÍNUO)                                    0.253169
# IDD_(CONTÍNUO)                                                     0.260897
# CONCEITO_MÉDIO_DE_GRADUAÇÃO                                        0.088698
# IGC_(CONTÍNUO)                                                     0.130635
# TDA                                                                0.994209
# SALARIO                                                            0.571371
# QT_VG_TOTAL_MEDIA                                                  0.592189
# ### Matriz de Correlação (Pearson) ###
#                                                     NOTA_PADRONIZADA_-_IDD  \
# NOTA_PADRONIZADA_-_IDD                                            1.000000
# NOTA_PADRONIZADA_-_ORGANIZAÇÃO_DIDÁTICO-PEDAGÓGICA                0.123684
# NOTA_PADRONIZADA_-_INFRAESTRUTURA_E_INSTALAÇÕES...                0.146072
# NOTA_PADRONIZADA_-_OPORTUNIDADE_DE_AMPLIAÇÃO_DA...                0.186829
# NOTA_PADRONIZADA_-_MESTRES                                        0.077338
# NOTA_PADRONIZADA_-_DOUTORES                                       0.098146
# MEDIA_CONCEITO_ENADE_(CONTÍNUO)                                   0.545648
# IDD_(CONTÍNUO)                                                    0.992764
# CONCEITO_MÉDIO_DE_GRADUAÇÃO                                       0.260531
# IGC_(CONTÍNUO)                                                    0.184989
# TDA                                                              -0.037513
# SALARIO                                                           0.027242
# QT_VG_TOTAL_MEDIA                                                -0.013960
#
#                                                     NOTA_PADRONIZADA_-_ORGANIZAÇÃO_DIDÁTICO-PEDAGÓGICA  \
# NOTA_PADRONIZADA_-_IDD                                                                       0.123684
# NOTA_PADRONIZADA_-_ORGANIZAÇÃO_DIDÁTICO-PEDAGÓGICA                                           1.000000
# NOTA_PADRONIZADA_-_INFRAESTRUTURA_E_INSTALAÇÕES...                                           0.746640
# NOTA_PADRONIZADA_-_OPORTUNIDADE_DE_AMPLIAÇÃO_DA...                                           0.662357
# NOTA_PADRONIZADA_-_MESTRES                                                                  -0.113450
# NOTA_PADRONIZADA_-_DOUTORES                                                                 -0.241842
# MEDIA_CONCEITO_ENADE_(CONTÍNUO)                                                             -0.112396
# IDD_(CONTÍNUO)                                                                               0.117646
# CONCEITO_MÉDIO_DE_GRADUAÇÃO                                                                 -0.115768
# IGC_(CONTÍNUO)                                                                              -0.250062
# TDA                                                                                          0.156997
# SALARIO                                                                                     -0.176817
# QT_VG_TOTAL_MEDIA                                                                           -0.162136
#
#                                                     NOTA_PADRONIZADA_-_INFRAESTRUTURA_E_INSTALAÇÕES_FÍSICAS  \
# NOTA_PADRONIZADA_-_IDD                                                                       0.146072
# NOTA_PADRONIZADA_-_ORGANIZAÇÃO_DIDÁTICO-PEDAGÓGICA                                           0.746640
# NOTA_PADRONIZADA_-_INFRAESTRUTURA_E_INSTALAÇÕES...                                           1.000000
# NOTA_PADRONIZADA_-_OPORTUNIDADE_DE_AMPLIAÇÃO_DA...                                           0.701039
# NOTA_PADRONIZADA_-_MESTRES                                                                  -0.031086
# NOTA_PADRONIZADA_-_DOUTORES                                                                 -0.114144
# MEDIA_CONCEITO_ENADE_(CONTÍNUO)                                                             -0.039660
# IDD_(CONTÍNUO)                                                                               0.144004
# CONCEITO_MÉDIO_DE_GRADUAÇÃO                                                                  0.073854
# IGC_(CONTÍNUO)                                                                              -0.101730
# TDA                                                                                          0.167587
# SALARIO                                                                                     -0.142587
# QT_VG_TOTAL_MEDIA                                                                           -0.090525
#
#                                                     NOTA_PADRONIZADA_-_OPORTUNIDADE_DE_AMPLIAÇÃO_DA_FORMAÇÃO  \
# NOTA_PADRONIZADA_-_IDD                                                                       0.186829
# NOTA_PADRONIZADA_-_ORGANIZAÇÃO_DIDÁTICO-PEDAGÓGICA                                           0.662357
# NOTA_PADRONIZADA_-_INFRAESTRUTURA_E_INSTALAÇÕES...                                           0.701039
# NOTA_PADRONIZADA_-_OPORTUNIDADE_DE_AMPLIAÇÃO_DA...                                           1.000000
# NOTA_PADRONIZADA_-_MESTRES                                                                   0.049991
# NOTA_PADRONIZADA_-_DOUTORES                                                                 -0.026499
# MEDIA_CONCEITO_ENADE_(CONTÍNUO)                                                              0.099143
# IDD_(CONTÍNUO)                                                                               0.185916
# CONCEITO_MÉDIO_DE_GRADUAÇÃO                                                                  0.169246
# IGC_(CONTÍNUO)                                                                               0.018629
# TDA                                                                                          0.113052
# SALARIO                                                                                     -0.001741
# QT_VG_TOTAL_MEDIA                                                                           -0.061964
#
#                                                     NOTA_PADRONIZADA_-_MESTRES  \
# NOTA_PADRONIZADA_-_IDD                                                0.077338
# NOTA_PADRONIZADA_-_ORGANIZAÇÃO_DIDÁTICO-PEDAGÓGICA                   -0.113450
# NOTA_PADRONIZADA_-_INFRAESTRUTURA_E_INSTALAÇÕES...                   -0.031086
# NOTA_PADRONIZADA_-_OPORTUNIDADE_DE_AMPLIAÇÃO_DA...                    0.049991
# NOTA_PADRONIZADA_-_MESTRES                                            1.000000
# NOTA_PADRONIZADA_-_DOUTORES                                           0.658061
# MEDIA_CONCEITO_ENADE_(CONTÍNUO)                                       0.322763
# IDD_(CONTÍNUO)                                                        0.081107
# CONCEITO_MÉDIO_DE_GRADUAÇÃO                                           0.526433
# IGC_(CONTÍNUO)                                                        0.500868
# TDA                                                                  -0.090511
# SALARIO                                                               0.075986
# QT_VG_TOTAL_MEDIA                                                     0.049242
#
#                                                     NOTA_PADRONIZADA_-_DOUTORES  \
# NOTA_PADRONIZADA_-_IDD                                                 0.098146
# NOTA_PADRONIZADA_-_ORGANIZAÇÃO_DIDÁTICO-PEDAGÓGICA                    -0.241842
# NOTA_PADRONIZADA_-_INFRAESTRUTURA_E_INSTALAÇÕES...                    -0.114144
# NOTA_PADRONIZADA_-_OPORTUNIDADE_DE_AMPLIAÇÃO_DA...                    -0.026499
# NOTA_PADRONIZADA_-_MESTRES                                             0.658061
# NOTA_PADRONIZADA_-_DOUTORES                                            1.000000
# MEDIA_CONCEITO_ENADE_(CONTÍNUO)                                        0.357661
# IDD_(CONTÍNUO)                                                         0.105047
# CONCEITO_MÉDIO_DE_GRADUAÇÃO                                            0.624088
# IGC_(CONTÍNUO)                                                         0.684672
# TDA                                                                   -0.168647
# SALARIO                                                                0.128234
# QT_VG_TOTAL_MEDIA                                                      0.152654
#
#                                                     MEDIA_CONCEITO_ENADE_(CONTÍNUO)  \
# NOTA_PADRONIZADA_-_IDD                                                     0.545648
# NOTA_PADRONIZADA_-_ORGANIZAÇÃO_DIDÁTICO-PEDAGÓGICA                        -0.112396
# NOTA_PADRONIZADA_-_INFRAESTRUTURA_E_INSTALAÇÕES...                        -0.039660
# NOTA_PADRONIZADA_-_OPORTUNIDADE_DE_AMPLIAÇÃO_DA...                         0.099143
# NOTA_PADRONIZADA_-_MESTRES                                                 0.322763
# NOTA_PADRONIZADA_-_DOUTORES                                                0.357661
# MEDIA_CONCEITO_ENADE_(CONTÍNUO)                                            1.000000
# IDD_(CONTÍNUO)                                                             0.551731
# CONCEITO_MÉDIO_DE_GRADUAÇÃO                                                0.529430
# IGC_(CONTÍNUO)                                                             0.538885
# TDA                                                                       -0.144910
# SALARIO                                                                    0.236414
# QT_VG_TOTAL_MEDIA                                                          0.062595
#
#                                                     IDD_(CONTÍNUO)  \
# NOTA_PADRONIZADA_-_IDD                                    0.992764
# NOTA_PADRONIZADA_-_ORGANIZAÇÃO_DIDÁTICO-PEDAGÓGICA        0.117646
# NOTA_PADRONIZADA_-_INFRAESTRUTURA_E_INSTALAÇÕES...        0.144004
# NOTA_PADRONIZADA_-_OPORTUNIDADE_DE_AMPLIAÇÃO_DA...        0.185916
# NOTA_PADRONIZADA_-_MESTRES                                0.081107
# NOTA_PADRONIZADA_-_DOUTORES                               0.105047
# MEDIA_CONCEITO_ENADE_(CONTÍNUO)                           0.551731
# IDD_(CONTÍNUO)                                            1.000000
# CONCEITO_MÉDIO_DE_GRADUAÇÃO                               0.267584
# IGC_(CONTÍNUO)                                            0.192255
# TDA                                                      -0.040826
# SALARIO                                                   0.033350
# QT_VG_TOTAL_MEDIA                                        -0.016473
#
#                                                     CONCEITO_MÉDIO_DE_GRADUAÇÃO  \
# NOTA_PADRONIZADA_-_IDD                                                 0.260531
# NOTA_PADRONIZADA_-_ORGANIZAÇÃO_DIDÁTICO-PEDAGÓGICA                    -0.115768
# NOTA_PADRONIZADA_-_INFRAESTRUTURA_E_INSTALAÇÕES...                     0.073854
# NOTA_PADRONIZADA_-_OPORTUNIDADE_DE_AMPLIAÇÃO_DA...                     0.169246
# NOTA_PADRONIZADA_-_MESTRES                                             0.526433
# NOTA_PADRONIZADA_-_DOUTORES                                            0.624088
# MEDIA_CONCEITO_ENADE_(CONTÍNUO)                                        0.529430
# IDD_(CONTÍNUO)                                                         0.267584
# CONCEITO_MÉDIO_DE_GRADUAÇÃO                                            1.000000
# IGC_(CONTÍNUO)                                                         0.885048
# TDA                                                                   -0.075450
# SALARIO                                                                0.228527
# QT_VG_TOTAL_MEDIA                                                      0.096360
#
#                                                     IGC_(CONTÍNUO)       TDA  \
# NOTA_PADRONIZADA_-_IDD                                    0.184989 -0.037513
# NOTA_PADRONIZADA_-_ORGANIZAÇÃO_DIDÁTICO-PEDAGÓGICA       -0.250062  0.156997
# NOTA_PADRONIZADA_-_INFRAESTRUTURA_E_INSTALAÇÕES...       -0.101730  0.167587
# NOTA_PADRONIZADA_-_OPORTUNIDADE_DE_AMPLIAÇÃO_DA...        0.018629  0.113052
# NOTA_PADRONIZADA_-_MESTRES                                0.500868 -0.090511
# NOTA_PADRONIZADA_-_DOUTORES                               0.684672 -0.168647
# MEDIA_CONCEITO_ENADE_(CONTÍNUO)                           0.538885 -0.144910
# IDD_(CONTÍNUO)                                            0.192255 -0.040826
# CONCEITO_MÉDIO_DE_GRADUAÇÃO                               0.885048 -0.075450
# IGC_(CONTÍNUO)                                            1.000000 -0.206237
# TDA                                                      -0.206237  1.000000
# SALARIO                                                   0.267881 -0.053115
# QT_VG_TOTAL_MEDIA                                         0.186605 -0.039785
#
#                                                      SALARIO  \
# NOTA_PADRONIZADA_-_IDD                              0.027242
# NOTA_PADRONIZADA_-_ORGANIZAÇÃO_DIDÁTICO-PEDAGÓGICA -0.176817
# NOTA_PADRONIZADA_-_INFRAESTRUTURA_E_INSTALAÇÕES... -0.142587
# NOTA_PADRONIZADA_-_OPORTUNIDADE_DE_AMPLIAÇÃO_DA... -0.001741
# NOTA_PADRONIZADA_-_MESTRES                          0.075986
# NOTA_PADRONIZADA_-_DOUTORES                         0.128234
# MEDIA_CONCEITO_ENADE_(CONTÍNUO)                     0.236414
# IDD_(CONTÍNUO)                                      0.033350
# CONCEITO_MÉDIO_DE_GRADUAÇÃO                         0.228527
# IGC_(CONTÍNUO)                                      0.267881
# TDA                                                -0.053115
# SALARIO                                             1.000000
# QT_VG_TOTAL_MEDIA                                   0.153138
#
#                                                     QT_VG_TOTAL_MEDIA
# NOTA_PADRONIZADA_-_IDD                                      -0.013960
# NOTA_PADRONIZADA_-_ORGANIZAÇÃO_DIDÁTICO-PEDAGÓGICA          -0.162136
# NOTA_PADRONIZADA_-_INFRAESTRUTURA_E_INSTALAÇÕES...          -0.090525
# NOTA_PADRONIZADA_-_OPORTUNIDADE_DE_AMPLIAÇÃO_DA...          -0.061964
# NOTA_PADRONIZADA_-_MESTRES                                   0.049242
# NOTA_PADRONIZADA_-_DOUTORES                                  0.152654
# MEDIA_CONCEITO_ENADE_(CONTÍNUO)                              0.062595
# IDD_(CONTÍNUO)                                              -0.016473
# CONCEITO_MÉDIO_DE_GRADUAÇÃO                                  0.096360
# IGC_(CONTÍNUO)                                               0.186605
# TDA                                                         -0.039785
# SALARIO                                                      0.153138
# QT_VG_TOTAL_MEDIA                                            1.000000
# ### Ranking TDA por IES ###
#                                                           TDA
# NOME_DA_IES
# INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOL...  26.486066
# INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOL...  24.130114
# Instituto Federal de Educação, Ciência e Tecnol...  22.632307
# INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOL...  22.190301
# INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOL...  21.091077
# ...                                                       ...
# FUNDAÇÃO UNIVERSIDADE FEDERAL DO ABC                 0.891756
# UNIVERSIDADE FEDERAL DO PARÁ                         0.775032
# INSTITUTO TECNOLÓGICO DE AERONÁUTICA                 0.450450
# INSTITUTO MILITAR DE ENGENHARIA                      0.000000
# UNIVERSIDADE FEDERAL DA PARAÍBA                      0.000000
#
# [105 rows x 1 columns]
